# %%
pip install psycopg2-binary

# %%
import random
import psycopg2

# %%
a = ['1','2','3','null']
b = ['5','6','7','null']
c = ['8','9','0','null']

conn = psycopg2.connect(database='data',user='trinity',password='trinity',host='127.0.0.1',port='5432')
cur = conn.cursor()

for i in range(2000000):
    w = random.choice(a)
    x = random.choice(b)
    z= random.randint(1,100)
    cur.execute("insert into tp.test0131 values(%s,%s,%s)",(w,x,z))
    conn.commit()

cur.close()
conn.close()

# %%
a = ['1','2','3','null']
b = ['5','6','7','null']
c = ['8','9','0','null']

for i in range(200):
    w = random.choice(a)
    x = random.choice(b)
    y = random.choice(c)
    z= random.randint(1,100)
    print(w,x,y,z)
# Out:
# null null 9 15
# 2 5 9 1
# 2 6 8 18
# 2 7 8 16
# 1 7 8 79
# 2 6 null 51
# 2 5 9 77
# null 7 null 73
# 3 7 9 99
# 1 null null 57
# 3 7 9 76
# 2 null 9 66
# 2 7 null 80
# null 5 9 65
# 3 6 8 36
# 3 6 null 85
# null 7 null 61
# 1 7 0 98
# 2 6 0 20
# 1 6 0 99
# 3 null 8 35
# 2 7 8 17
# 1 null 8 16
# 3 null null 93
# 2 6 null 50
# null 5 null 80
# 3 6 null 46
# 3 5 9 22
# 3 null 9 70
# null 6 null 98
# 3 5 8 73
# 3 6 0 54
# 2 6 9 41
# 1 7 8 17
# 3 null null 52
# 3 6 null 86
# 1 7 null 54
# 2 7 8 95
# 2 5 0 16
# 2 5 null 33
# 3 null null 48
# 3 null 8 67
# 1 7 0 30
# 2 null null 49
# 1 null null 11
# null null 8 33
# null 7 null 76
# 2 6 0 73
# 2 7 8 91
# 1 5 9 29
# 3 5 0 46
# null 7 null 1
# 1 6 null 23
# null 5 0 57
# 3 6 8 63
# 3 7 9 71
# 1 7 9 25
# 2 6 null 43
# 3 null 9 44
# 2 null 9 81
# null 7 9 47
# 2 5 0 76
# 3 5 8 18
# 3 null 8 57
# 2 7 null 12
# 2 6 8 41
# null null 9 11
# 1 6 0 43
# null null null 45
# 1 null 8 5
# 2 7 9 37
# 1 7 0 97
# 2 6 8 72
# 2 6 0 7
# 3 5 8 97
# ...

# %%
a = ['1','2','3','null']
b = ['5','6','7','null']
c = ['8','9','0','null']

x = 0
while x < 20:
    a = a[]
    b = random.choice(b)
    c = random.sample(c,1)
    d= random.randint(1,100)
    print(a,b,c,d)
    x = x + 1
